# %% [markdown]
# ### 01_fund_master

# %%
import pandas as pd

# %%
fundM_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\01_fund_master.csv"

# %%
fundM_raw = pd.read_csv(fundM_path)

# %%
fundM_raw.shape
# Out:
# (40, 15)

# %%
fundM_raw.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
fundM_raw.tail()
# Out:
#     amfi_code       fund_house  \
# 35     148568   Mirae Asset MF
# 36     148569   Mirae Asset MF
# 37     149322  DSP Mutual Fund
# 38     149323  DSP Mutual Fund
# 39     149324  DSP Mutual Fund
#
#                                           scheme_name category  \
# 35  Mirae Asset Emerging Bluechip Fund - Regular -...   Equity
# 36      Mirae Asset Tax Saver Fund - Regular - Growth   Equity
# 37         DSP Top 100 Equity Fund - Regular - Growth   Equity
# 38                 DSP Midcap Fund - Regular - Growth   Equity
# 39              DSP Small Cap Fund - Regular - Growth   Equity
#
#        sub_category     plan launch_date                   benchmark  \
# 35  Large & Mid Cap  Regular  2010-07-09  NIFTY Large Midcap 250 TRI
# 36             ELSS  Regular  2015-12-28               NIFTY 500 TRI
# 37        Large Cap  Regular  2003-03-10               NIFTY 100 TRI
# 38          Mid Cap  Regular  2006-11-16        NIFTY Midcap 150 TRI
# ...

# %%
fundM_raw.dtypes
# Out:
# amfi_code               int64
# fund_house                str
# scheme_name               str
# category                  str
# sub_category              str
# plan                      str
# launch_date               str
# benchmark                 str
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager              str
# risk_category             str
# sebi_category_code        str
# dtype: object

# %%
print(fundM_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     str
#  2   scheme_name         40 non-null     str
#  3   category            40 non-null     str
#  4   sub_category        40 non-null     str
#  5   plan                40 non-null     str
#  6   launch_date         40 non-null     str
#  7   benchmark           40 non-null     str
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     str
#  13  risk_category       40 non-null     str
#  14  sebi_category_code  40 non-null     str
# dtypes: float64(2), int64(3), str(10)
# memory usage: 4.8 KB
# None

# %%
print(fundM_raw.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %% [markdown]
# ### 02 NAV HISTORY

# %%
navH_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\02_nav_history.csv"

# %%
nahH_raw = pd.read_csv(navH_path)

# %%
nahH_raw.shape
# Out:
# (46000, 3)

# %%
nahH_raw.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
nahH_raw.tail()
# Out:
#        amfi_code        date       nav
# 45995     149324  2026-05-25  292.4810
# 45996     149324  2026-05-26  291.2707
# 45997     149324  2026-05-27  288.8007
# 45998     149324  2026-05-28  280.6873
# 45999     149324  2026-05-29  279.7511

# %%
nahH_raw.dtypes
# Out:
# amfi_code      int64
# date             str
# nav          float64
# dtype: object

# %%
print(nahH_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  str
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 1.1 MB
# None

# %%
print(nahH_raw.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45995    False
# 45996    False
# 45997    False
# 45998    False
# 45999    False
# Length: 46000, dtype: bool

# %% [markdown]
# ### 03_aum_by_fund_house

# %%
aum_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\03_aum_by_fund_house.csv"

# %%
aum_raw = pd.read_csv(aum_path)

# %%
aum_raw.shape
# Out:
# (90, 5)

# %%
aum_raw.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
aum_raw.tail()
# Out:
#           date                fund_house  aum_lakh_crore  aum_crore  \
# 85  2025-12-31  Aditya Birla Sun Life MF             4.6     460000
# 86  2025-12-31          Axis Mutual Fund             3.5     350000
# 87  2025-12-31           UTI Mutual Fund             4.1     410000
# 88  2025-12-31            Mirae Asset MF             2.9     290000
# 89  2025-12-31           DSP Mutual Fund             2.3     230000
#
#     num_schemes
# 85          199
# 86           95
# 87          142
# 88           56
# 89           88

# %%
aum_raw.dtypes
# Out:
# date                  str
# fund_house            str
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object

# %%
print(aum_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            90 non-null     str
#  1   fund_house      90 non-null     str
#  2   aum_lakh_crore  90 non-null     float64
#  3   aum_crore       90 non-null     int64
#  4   num_schemes     90 non-null     int64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 3.6 KB
# None

# %%
print(aum_raw.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 85    False
# 86    False
# 87    False
# 88    False
# 89    False
# Length: 90, dtype: bool

# %% [markdown]
# ### 04_monthly_sip_inflows

# %%
sip_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\04_monthly_sip_inflows.csv"

# %%
sip_raw = pd.read_csv(sip_path)

# %%
sip_raw.shape
# Out:
# (48, 6)

# %%
sip_raw.head()
# Out:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
sip_raw.tail()
# Out:
#       month  sip_inflow_crore  active_sip_accounts_crore  \
# 43  2025-08             28265                       8.85
# 44  2025-09             29361                       9.00
# 45  2025-10             29529                       9.10
# 46  2025-11             30200                       9.20
# 47  2025-12             31002                       9.35
#
#     new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 43                   9.80               15.18           20.04
# 44                  10.50               15.38           19.80
# 45                   9.45               15.55           16.61
# 46                   9.10               15.72           19.27
# 47                   9.80               15.90           17.17

# %%
sip_raw.dtypes
# Out:
# month                            str
# sip_inflow_crore               int64
# active_sip_accounts_crore    float64
# new_sip_accounts_lakh        float64
# sip_aum_lakh_crore           float64
# yoy_growth_pct               float64
# dtype: object

# %%
print(sip_raw.info()) ### here in yoy_growth_pct column contains 12 null values out of total 48 entries
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      48 non-null     str
#  1   sip_inflow_crore           48 non-null     int64
#  2   active_sip_accounts_crore  48 non-null     float64
#  3   new_sip_accounts_lakh      48 non-null     float64
#  4   sip_aum_lakh_crore         48 non-null     float64
#  5   yoy_growth_pct             36 non-null     float64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 2.4 KB
# None

# %%
print(sip_raw.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# dtype: bool

# %% [markdown]
# ### 05_category_inflows

# %%
inflow_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\05_category_inflows.csv"

# %%
inflow_raw = pd.read_csv(inflow_path)

# %%
inflow_raw.shape
# Out:
# (144, 3)

# %%
inflow_raw.head()
# Out:
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
inflow_raw.tail()
# Out:
#        month           category  net_inflow_crore
# 139  2025-03  Sectoral/Thematic            8614.0
# 140  2025-03             Liquid           38681.0
# 141  2025-03     Short Duration            4886.0
# 142  2025-03               Gilt             956.0
# 143  2025-03             Hybrid            2830.0

# %%
inflow_raw.dtypes
# Out:
# month                   str
# category                str
# net_inflow_crore    float64
# dtype: object

# %%
print(inflow_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             144 non-null    str
#  1   category          144 non-null    str
#  2   net_inflow_crore  144 non-null    float64
# dtypes: float64(1), str(2)
# memory usage: 3.5 KB
# None

# %%
print(inflow_raw.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# Length: 144, dtype: bool

# %% [markdown]
# ### 06_industry_folio_count

# %%
fCount_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\06_industry_folio_count.csv"

# %%
fCount_raw = pd.read_csv(fCount_path)

# %%
fCount_raw.shape
# Out:
# (21, 6)

# %%
fCount_raw.head()
# Out:
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
fCount_raw.tail()
# Out:
#       month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 16  2025-07               24.57                17.20               3.44
# 17  2025-08               24.89                17.42               3.48
# 18  2025-09               25.19                17.63               3.53
# 19  2025-10               25.60                17.92               3.58
# 20  2025-12               26.12                18.28               3.66
#
#     hybrid_folios_crore  others_folios_crore
# 16                 1.47                 2.46
# 17                 1.49                 2.49
# 18                 1.51                 2.52
# 19                 1.54                 2.56
# 20                 1.57                 2.61

# %%
fCount_raw.dtypes
# Out:
# month                      str
# total_folios_crore     float64
# equity_folios_crore    float64
# debt_folios_crore      float64
# hybrid_folios_crore    float64
# others_folios_crore    float64
# dtype: object

# %%
print(fCount_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                21 non-null     str
#  1   total_folios_crore   21 non-null     float64
#  2   equity_folios_crore  21 non-null     float64
#  3   debt_folios_crore    21 non-null     float64
#  4   hybrid_folios_crore  21 non-null     float64
#  5   others_folios_crore  21 non-null     float64
# dtypes: float64(5), str(1)
# memory usage: 1.1 KB
# None

# %%
print(fCount_raw.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %% [markdown]
# ### 07_scheme_performance

# %%
scheme_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\07_scheme_performance.csv"

# %%
scheme_raw = pd.read_csv(scheme_path)

# %%
scheme_raw.shape
# Out:
# (40, 19)

# %%
scheme_raw.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
scheme_raw.tail()
# Out:
#     amfi_code                                        scheme_name  \
# 35     148568  Mirae Asset Emerging Bluechip Fund - Regular -...
# 36     148569      Mirae Asset Tax Saver Fund - Regular - Growth
# 37     149322         DSP Top 100 Equity Fund - Regular - Growth
# 38     149323                 DSP Midcap Fund - Regular - Growth
# 39     149324              DSP Small Cap Fund - Regular - Growth
#
#          fund_house         category     plan  return_1yr_pct  return_3yr_pct  \
# 35   Mirae Asset MF  Large & Mid Cap  Regular           14.91           14.56
# 36   Mirae Asset MF             ELSS  Regular           11.16           13.58
# 37  DSP Mutual Fund        Large Cap  Regular           11.96           12.82
# 38  DSP Mutual Fund          Mid Cap  Regular           14.12           17.16
# 39  DSP Mutual Fund        Small Cap  Regular           20.20           20.08
#
#     return_5yr_pct  benchmark_3yr_pct  alpha  beta  sharpe_ratio  \
# ...

# %%
scheme_raw.dtypes
# Out:
# amfi_code               int64
# scheme_name               str
# fund_house                str
# category                  str
# plan                      str
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade                str
# dtype: object

# %%
print(scheme_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   scheme_name         40 non-null     str
#  2   fund_house          40 non-null     str
#  3   category            40 non-null     str
#  4   plan                40 non-null     str
#  5   return_1yr_pct      40 non-null     float64
#  6   return_3yr_pct      40 non-null     float64
#  7   return_5yr_pct      40 non-null     float64
#  8   benchmark_3yr_pct   40 non-null     float64
#  9   alpha               40 non-null     float64
#  10  beta                40 non-null     float64
#  11  sharpe_ratio        40 non-null     float64
#  12  sortino_ratio       40 non-null     float64
#  13  std_dev_ann_pct     40 non-null     float64
#  14  max_drawdown_pct    40 non-null     float64
#  15  aum_crore           40 non-null     int64
# ...

# %%
print(scheme_raw.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %% [markdown]
# ### 08_investor_transactions

# %%
iTran_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\08_investor_transactions.csv"

# %%
iTran_raw = pd.read_csv(iTran_path)

# %%
iTran_raw.shape
# Out:
# (32778, 13)

# %%
iTran_raw.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
iTran_raw.tail()
# Out:
#       investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 32773   INV003340       2025-05-30     101207          Lumpsum      168029
# 32774   INV001838       2025-05-30     119093              SIP        2175
# 32775   INV000074       2025-05-30     120504              SIP       25998
# 32776   INV002929       2025-05-30     148568              SIP         459
# 32777   INV001852       2025-05-30     118633       Redemption      226721
#
#                 state       city city_tier age_group  gender  \
# 32773  Madhya Pradesh     Indore       T30     26-35    Male
# 32774   Uttar Pradesh     Kanpur       B30     46-55    Male
# 32775       Rajasthan     Jaipur       T30     26-35  Female
# 32776     West Bengal    Kolkata       T30     26-35    Male
# 32777       Telangana  Hyderabad       T30     26-35    Male
#
#        annual_income_lakh payment_mode kyc_status
# 32773                22.5  Net Banking   Verified
# ...

# %%
iTran_raw.dtypes
# Out:
# investor_id               str
# transaction_date          str
# amfi_code               int64
# transaction_type          str
# amount_inr              int64
# state                     str
# city                      str
# city_tier                 str
# age_group                 str
# gender                    str
# annual_income_lakh    float64
# payment_mode              str
# kyc_status                str
# dtype: object

# %%
print(iTran_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32778 entries, 0 to 32777
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   investor_id         32778 non-null  str
#  1   transaction_date    32778 non-null  str
#  2   amfi_code           32778 non-null  int64
#  3   transaction_type    32778 non-null  str
#  4   amount_inr          32778 non-null  int64
#  5   state               32778 non-null  str
#  6   city                32778 non-null  str
#  7   city_tier           32778 non-null  str
#  8   age_group           32778 non-null  str
#  9   gender              32778 non-null  str
#  10  annual_income_lakh  32778 non-null  float64
#  11  payment_mode        32778 non-null  str
#  12  kyc_status          32778 non-null  str
# dtypes: float64(1), int64(2), str(10)
# memory usage: 3.3 MB
# None

# %%
print(iTran_raw.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32773    False
# 32774    False
# 32775    False
# 32776    False
# 32777    False
# Length: 32778, dtype: bool

# %% [markdown]
# ### 09_portfolio_holdings

# %%
pfolio_path =r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\09_portfolio_holdings.csv"

# %%
pfolio_raw = pd.read_csv(pfolio_path)

# %%
pfolio_raw.shape
# Out:
# (322, 8)

# %%
pfolio_raw.head()
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
pfolio_raw.tail()
# Out:
#      amfi_code stock_symbol                 stock_name     sector  weight_pct  \
# 317     149324     DIVISLAB        Divi's Laboratories     Pharma        9.54
# 318     149324   BHARTIARTL          Bharti Airtel Ltd    Telecom        1.79
# 319     149324          TCS  Tata Consultancy Services         IT       13.17
# 320     149324   INDUSINDBK          IndusInd Bank Ltd    Banking        7.63
# 321     149324         NTPC                   NTPC Ltd  Utilities        2.04
#
#      market_value_cr  current_price_inr portfolio_date
# 317           855.88            7453.05     2025-12-31
# 318           969.71             924.41     2025-12-31
# 319          1637.69            1927.89     2025-12-31
# 320          1387.30            3208.86     2025-12-31
# 321          1303.55            5797.95     2025-12-31

# %%
pfolio_raw.dtypes
# Out:
# amfi_code              int64
# stock_symbol             str
# stock_name               str
# sector                   str
# weight_pct           float64
# market_value_cr      float64
# current_price_inr    float64
# portfolio_date           str
# dtype: object

# %%
print(pfolio_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   amfi_code          322 non-null    int64
#  1   stock_symbol       322 non-null    str
#  2   stock_name         322 non-null    str
#  3   sector             322 non-null    str
#  4   weight_pct         322 non-null    float64
#  5   market_value_cr    322 non-null    float64
#  6   current_price_inr  322 non-null    float64
#  7   portfolio_date     322 non-null    str
# dtypes: float64(3), int64(1), str(4)
# memory usage: 20.3 KB
# None

# %%
print(pfolio_raw.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 317    False
# 318    False
# 319    False
# 320    False
# 321    False
# Length: 322, dtype: bool

# %% [markdown]
# ### 10_benchmark_indices

# %%
indices_path = r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\10_benchmark_indices.csv"

# %%
indices_raw = pd.read_csv(indices_path)

# %%
indices_raw.shape
# Out:
# (8050, 3)

# %%
indices_raw.head()
# Out:
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
indices_raw.tail()
# Out:
#             date   index_name  close_value
# 8045  2026-05-25  CRISIL_GILT      2278.26
# 8046  2026-05-26  CRISIL_GILT      2281.42
# 8047  2026-05-27  CRISIL_GILT      2281.30
# 8048  2026-05-28  CRISIL_GILT      2298.35
# 8049  2026-05-29  CRISIL_GILT      2302.79

# %%
indices_raw.dtypes
# Out:
# date               str
# index_name         str
# close_value    float64
# dtype: object

# %%
print(indices_raw.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8050 entries, 0 to 8049
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         8050 non-null   str
#  1   index_name   8050 non-null   str
#  2   close_value  8050 non-null   float64
# dtypes: float64(1), str(2)
# memory usage: 188.8 KB
# None

# %%
print(indices_raw.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8045    False
# 8046    False
# 8047    False
# 8048    False
# 8049    False
# Length: 8050, dtype: bool
