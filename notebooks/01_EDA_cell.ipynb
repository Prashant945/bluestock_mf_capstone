# %%
import pandas as pd

# %%
FundMaster_data = pd.read_csv(r"C:\Users\prash\Downloads\git_project\bluestock_mf_capstone\data\raw\01_fund_master.csv")
FundMaster_data
# Out:
#     amfi_code                fund_house  \
# 0      119551           SBI Mutual Fund
# 1      119552           SBI Mutual Fund
# 2      119598           SBI Mutual Fund
# 3      119599           SBI Mutual Fund
# 4      119120           SBI Mutual Fund
# 5      100016          HDFC Mutual Fund
# 6      125497          HDFC Mutual Fund
# 7      100033          HDFC Mutual Fund
# 8      125498          HDFC Mutual Fund
# 9      100025          HDFC Mutual Fund
# 10     120503       ICICI Prudential MF
# 11     120504       ICICI Prudential MF
# 12     120505       ICICI Prudential MF
# 13     120506       ICICI Prudential MF
# 14     120507       ICICI Prudential MF
# 15     118632           Nippon India MF
# 16     118633           Nippon India MF
# 17     118634           Nippon India MF
# 18     118635           Nippon India MF
# 19     118636           Nippon India MF
# 20     120841         Kotak Mahindra MF
# 21     120842         Kotak Mahindra MF
# ...

# %%
FundMaster_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     str
#  2   scheme_name         40 non-null     str
#  3   category            40 non-null     str
#  4   sub_category        40 non-null     str
#  5   plan                40 non-null     str
#  6   launch_date         40 non-null     str
#  7   benchmark           40 non-null     str
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     str
#  13  risk_category       40 non-null     str
#  14  sebi_category_code  40 non-null     str
# dtypes: float64(2), int64(3), str(10)
# memory usage: 4.8 KB

# %%
df =pd.DataFrame(FundMaster_data)

# %%
print("Unique Fund Houses", df['fund_house'].unique())
# Out:
# Unique Fund Houses <StringArray>
# [         'SBI Mutual Fund',         'HDFC Mutual Fund',
#       'ICICI Prudential MF',          'Nippon India MF',
#         'Kotak Mahindra MF',         'Axis Mutual Fund',
#  'Aditya Birla Sun Life MF',          'UTI Mutual Fund',
#            'Mirae Asset MF',          'DSP Mutual Fund']
# Length: 10, dtype: str

# %%
print("Unique Fund Houses\n", FundMaster_data['fund_house'].unique())
print("\n")
print("\n")
print("Unique Categories\n", FundMaster_data['category'].unique())
print("\n")
print("\n")
print("unique Sub-category\n", FundMaster_data['sub_category'].unique())
print("\n")
print("\n")
print("Risk Category/Grade\n", FundMaster_data['risk_category'].unique())
# Out:
# Unique Fund Houses
#  <StringArray>
# [         'SBI Mutual Fund',         'HDFC Mutual Fund',
#       'ICICI Prudential MF',          'Nippon India MF',
#         'Kotak Mahindra MF',         'Axis Mutual Fund',
#  'Aditya Birla Sun Life MF',          'UTI Mutual Fund',
#            'Mirae Asset MF',          'DSP Mutual Fund']
# Length: 10, dtype: str
#
#
#
#
# Unique Categories
#  <StringArray>
# ['Equity', 'Debt']
# Length: 2, dtype: str
#
#
#
#
# unique Sub-category
#  <StringArray>
# [      'Large Cap',       'Small Cap',            'Gilt',         'Mid Cap',
#   'Short Duration',           'Value',          'Liquid',       'Index/ETF',
#        'Flexi Cap',           'Index', 'Large & Mid Cap',            'ELSS']
# Length: 12, dtype: str
#
#
#
#
# Risk Category/Grade
#  <StringArray>
# ['Moderate', 'Very High', 'Low', 'High', 'Moderately High']
# Length: 5, dtype: str

# %%
###
